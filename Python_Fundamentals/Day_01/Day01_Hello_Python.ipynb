# %% [markdown]
# # Title

# %% [markdown]
# Day 1 - Introduction to Python

# %% [markdown]
# # Notes

# %% [markdown]
# What I Learnt
#
# - What Python is
# - How to use print()
# - How to write my first Python program

# %% [markdown]
# # Code

# %%
print("Hello, Wolrd!")

print("My is Yusuf, I'm Studying Computer Engineering.")
print(" This is my Day 1 of AI Engineering Journey.")
# Out:
# Hello, Wolrd!
# My is Yusuf, I'm Studying Computer Engineering.
#  This is my Day 1 of AI Engineering Journey.

# %% [markdown]
# ## Reflection
#
# Today I started my AI Engineering journey.
# I learned how to print text in python
