# %% [markdown]
# # Title

# %% [markdown]
# # Day 2 - Variables & Data Types

# %% [markdown]
# # Notes

# %% [markdown]
# ## What i learnt
#
# - Variables
# - Strings
# - Integers
# - Floats
# - Booleans

# %% [markdown]
# # Code

# %%
name = "Yusuf"
age = 20

print(name)
print(age)
# Out:
# Yusuf
# 20

# %%
name = input("Enter your name: ")
print(" Welcome", name)
# Out:
# Enter your name: Ummusalmah
#  Welcome Ummusalmah

# %% [markdown]
# # Reflection

# %% [markdown]
# Today i learned how variables store information and how to recieve user input
