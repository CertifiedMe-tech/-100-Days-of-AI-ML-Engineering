# %% [markdown]
# # Title

# %% [markdown]
# # Day 3 - Input, Output & String Formatting

# %% [markdown]
# # Notes

# %% [markdown]
# ## What i Learnt
#
# - Input()
# - Output()
# - f-strings
# - Escape characters

# %% [markdown]
# # Code

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")

print(f"Welcome {name}")
print(f" You are {age} years old.")
# Out:
# Enter your name: yusf
# Enter your age: 23
# Welcome yusf
#  You are 23 years old.

# %% [markdown]
# # Student Information Card

# %%
name = input("Name: ")
age = input("Age: ")
department = input("Department: ")
university = input("University: ")
career = input("Dream Career: ")

print("\n==============STUDENT CARD ==========")
print(f"Name: {name}")
print(f"Age: {age}")
print(f"Department: {department}")
print(f"University: {university}")
print(f"Dream Career: {career}")
print("=======================================")
# Out:
# Name: YUSUF
# Age: 20
# Department: CPE
# University: FUTMINNA
# Dream Career: AI ENGINEER
#
# ==============STUDENT CARD ==========
# Name: YUSUF
# Age: 20
# Department: CPE
# University: FUTMINNA
# Dream Career: AI ENGINEER
# ==============================
